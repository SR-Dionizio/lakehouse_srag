# %%
import os

from pyspark.sql import SparkSession
import pyspark.sql.functions as F

# %%
spark = SparkSession.builder \
    .appName("SragSilver") \
    .master("local[*]") \
    .getOrCreate()

# %%
spark.sparkContext.setLogLevel("ERROR")

# %%
base_dir = os.path.abspath(os.path.join(os.getcwd(), "../")) 
data_path = os.path.join(base_dir, "data/bronze/")
df = spark.read.csv(
    data_path,
    header=True,
    inferSchema=True,
    sep=";"
)

# %%
date_columns = [
    'DT_NOTIFIC', 'DT_SIN_PRI', 'DT_NASC', 'DT_UT_DOSE',
    'DT_VAC_MAE', 'DT_DOSEUNI', 'DT_1_DOSE', 'DT_2_DOSE', 
    'DT_ANTIVIR', 'DT_INTERNA', 'DT_ENTUTI', 'DT_SAIDUTI',
    'DT_COLETA', 'DT_PCR', 'DT_RES', 'DT_EVOLUCA',
    'DT_ENCERRA', 'DT_DIGITA'
]

for col in date_columns:
    df = df.withColumn(col, F.to_date(F.col(col), 'dd/MM/yyyy'))

# %%
int_columns = [
    'SEM_NOT', 'SEM_PRI', 'NU_IDADE_N', 'TP_IDADE', 'CS_GESTANT',
    'CS_RACA', 'CS_ESCOL_N', 'CO_PAIS', 'CS_ZONA', 'SURTO_SG',
    'NOSOCOMIAL', 'AVE_SUINO', 'FEBRE', 'TOSSE', 'GARGANTA', 'DISPNEIA',
    'DESC_RESP', 'SATURACAO', 'DIARREIA', 'VOMITO', 'OUTRO_SIN',
    'PUERPERA', 'FATOR_RISC', 'CARDIOPATI', 'HEMATOLOGI', 'SIND_DOWN', 
    'HEPATICA', 'ASMA', 'DIABETES', 'NEUROLOGIC', 'PNEUMOPATI', 
    'IMUNODEPRE', 'RENAL', 'OBESIDADE', 'OBES_IMC', 'OUT_MORBI',
    'VACINA', 'MAE_VAC', 'ANTIVIRAL', 'TP_ANTIVIR', 'HOSPITAL',
    'UTI', 'SUPORT_VEN', 'RAIOX_RES', 'AMOSTRA', 'TP_AMOSTRA', 
    'PCR_RESUL', 'PCR_RESUL', 'POS_PCRFLU', 'PCR_FLUASU',
    'FLUASU_OUT', 'PCR_FLUBLI', 'FLUBLI_OUT', 'POS_PCROUT','PCR_VSR',
    'PCR_PARA1', 'PCR_PARA2', 'PCR_PARA3', 'PCR_PARA4', 'PCR_ADENO', 
    'PCR_BOCA','PCR_RINO', 'PCR_OUTRO', 'PCR_METAP', 'CLASSI_FIN',
    'CLASSI_OUT', 'CRITERIO', 'EVOLUCAO', 'HISTO_VGM', 'PAIS_VGM', 
    'CO_PS_VGM', 'LO_PS_VGM', 'DT_VGM', 'DT_RT_VGM', 'PCR_SARS2', 'PAC_COCBO',
    'PAC_DSCBO', 'OUT_ANIM', 'DOR_ABD', 'FADIGA', 'PERD_OLFT', 'PERD_PALA',
    'TOMO_RES', 'TP_TES_AN', 'POS_AN_FLU', 'TP_FLU_AN', 'POS_AN_OUT',
    'AN_SARS2', 'AN_VSR', 'AN_PARA1', 'AN_PARA2', 'AN_PARA3', 'AN_ADENO',
    'AN_OUTRO', 'DS_AN_OUT', 'TP_AM_SOR', 'SOR_OUT', 'RES_IGG', 'RES_IGM',
    'RES_IGA', 'ESTRANG', 'VACINA_COV', 'TRAT_COV', 'TIPO_TRAT',
    'OUT_TRAT', 'CO_DETEC', 'VG_OMS', 'VG_OMSOUT', 'VG_LIN', 'VG_MET',
    'VG_METOUT', 'VG_DTRES', 'VG_ENC', 'VG_REINF', 'REINF', 'FAB_ADIC',
    'LOT_RE_BI', 'FAB_RE_BI', 'DOSE_ADIC', 'DOS_RE_BI', 'LOTE_ADIC', 'TABAG'
]

for int_col in int_columns:
    df = df.withColumn(int_col, F.col(int_col).cast('int'))

# %%
df.show()
# Out:
# +----------+-------+----------+-------+---------+--------------------+----------+-------------------+----------+--------------------+----------+-------+----------+----------+--------+---------+----------+-------+----------+-------+-------+-----+--------------------+----------+--------------------+----------+-------+--------+----------+---------+-----+-----+--------+--------+---------+---------+--------+------+---------+-------------------+--------+----------+----------+----------+---------+--------+----+--------+----------+----------+----------+-----+---------+--------+---------+--------------------+------+----------+-------+----------+----------+----------+---------+---------+---------+----------+---------+----------+--------+----------+----------+--------------------+----------+--------------+----------+----+----------+----------+----------+---------+--------------------+----------+-------+----------+----------+-----------------+---------+----------+----------+----------+----------+----------+----------+----------+----------+-------+---------+---------+---------+---------+---------+---------+--------+--------+---------+----------------+----------+----------+--------+--------+----------+----------+----------+---------+--------+---------+---------+------+---------+---------+---------+---------+--------+-------+------+---------+---------+--------+-----------+----------+---------+----------+------+----------+---------+----------+--------+------+--------+--------+--------+--------+--------+---------+---------+-------+---------+------+-------+------+-------+-------+-------+-------+----------+----------+----------+----------+--------------------+--------------------+--------------------+--------------------+----------+------------+----------+----------+----------+--------------------+----------+--------+---------+--------+----------+--------+------+---------+------+------+---------+--------+------+--------+-----+--------+---------+---------+---------+---------+---------+-----+
# |DT_NOTIFIC|SEM_NOT|DT_SIN_PRI|SEM_PRI|SG_UF_NOT|          ID_REGIONA|CO_REGIONA|         ID_MUNICIP|CO_MUN_NOT|          ID_UNIDADE|CO_UNI_NOT|CS_SEXO|   DT_NASC|NU_IDADE_N|TP_IDADE|COD_IDADE|CS_GESTANT|CS_RACA|CS_ESCOL_N|ID_PAIS|CO_PAIS|SG_UF|          ID_RG_RESI|CO_RG_RESI|          ID_MN_RESI|CO_MUN_RES|CS_ZONA|SURTO_SG|NOSOCOMIAL|AVE_SUINO|FEBRE|TOSSE|GARGANTA|DISPNEIA|DESC_RESP|SATURACAO|DIARREIA|VOMITO|OUTRO_SIN|          OUTRO_DES|PUERPERA|FATOR_RISC|CARDIOPATI|HEMATOLOGI|SIND_DOWN|HEPATICA|ASMA|DIABETES|NEUROLOGIC|PNEUMOPATI|IMUNODEPRE|RENAL|OBESIDADE|OBES_IMC|OUT_MORBI|           MORB_DESC|VACINA|DT_UT_DOSE|MAE_VAC|DT_VAC_MAE|M_AMAMENTA|DT_DOSEUNI|DT_1_DOSE|DT_2_DOSE|ANTIVIRAL|TP_ANTIVIR|OUT_ANTIV|DT_ANTIVIR|HOSPITAL|DT_INTERNA|SG_UF_INTE|          ID_RG_INTE|CO_RG_INTE|    ID_MN_INTE|CO_MU_INTE| UTI| DT_ENTUTI|DT_SAIDUTI|SUPORT_VEN|RAIOX_RES|           RAIOX_OUT|  DT_RAIOX|AMOSTRA| DT_COLETA|TP_AMOSTRA|        OUT_AMOST|PCR_RESUL|    DT_PCR|POS_PCRFLU|TP_FLU_PCR|PCR_FLUASU|FLUASU_OUT|PCR_FLUBLI|FLUBLI_OUT|POS_PCROUT|PCR_VSR|PCR_PARA1|PCR_PARA2|PCR_PARA3|PCR_PARA4|PCR_ADENO|PCR_METAP|PCR_BOCA|PCR_RINO|PCR_OUTRO|      DS_PCR_OUT|CLASSI_FIN|CLASSI_OUT|CRITERIO|EVOLUCAO|DT_EVOLUCA|DT_ENCERRA| DT_DIGITA|HISTO_VGM|PAIS_VGM|CO_PS_VGM|LO_PS_VGM|DT_VGM|DT_RT_VGM|PCR_SARS2|PAC_COCBO|PAC_DSCBO|OUT_ANIM|DOR_ABD|FADIGA|PERD_OLFT|PERD_PALA|TOMO_RES|   TOMO_OUT|   DT_TOMO|TP_TES_AN| DT_RES_AN|RES_AN|POS_AN_FLU|TP_FLU_AN|POS_AN_OUT|AN_SARS2|AN_VSR|AN_PARA1|AN_PARA2|AN_PARA3|AN_ADENO|AN_OUTRO|DS_AN_OUT|TP_AM_SOR|SOR_OUT|DT_CO_SOR|TP_SOR|OUT_SOR|DT_RES|RES_IGG|RES_IGM|RES_IGA|ESTRANG|VACINA_COV|DOSE_1_COV|DOSE_2_COV|  DOSE_REF|           FAB_COV_1|           FAB_COV_2|          FAB_COVREF|          LAB_PR_COV|LOTE_1_COV|  LOTE_2_COV|  LOTE_REF|FNT_IN_COV| DOSE_2REF|          FAB_COVRF2| LOTE_REF2|TRAT_COV|TIPO_TRAT|OUT_TRAT|DT_TRT_COV|CO_DETEC|VG_OMS|VG_OMSOUT|VG_LIN|VG_MET|VG_METOUT|VG_DTRES|VG_ENC|VG_REINF|REINF|FAB_ADIC|LOT_RE_BI|FAB_RE_BI|DOSE_ADIC|DOS_RE_BI|LOTE_ADIC|TABAG|
# +----------+-------+----------+-------+---------+--------------------+----------+-------------------+----------+--------------------+----------+-------+----------+----------+--------+---------+----------+-------+----------+-------+-------+-----+--------------------+----------+--------------------+----------+-------+--------+----------+---------+-----+-----+--------+--------+---------+---------+--------+------+---------+-------------------+--------+----------+----------+----------+---------+--------+----+--------+----------+----------+----------+-----+---------+--------+---------+--------------------+------+----------+-------+----------+----------+----------+---------+---------+---------+----------+---------+----------+--------+----------+----------+--------------------+----------+--------------+----------+----+----------+----------+----------+---------+--------------------+----------+-------+----------+----------+-----------------+---------+----------+----------+----------+----------+----------+----------+----------+----------+-------+---------+---------+---------+---------+---------+---------+--------+--------+---------+----------------+----------+----------+--------+--------+----------+----------+----------+---------+--------+---------+---------+------+---------+---------+---------+---------+--------+-------+------+---------+---------+--------+-----------+----------+---------+----------+------+----------+---------+----------+--------+------+--------+--------+--------+--------+--------+---------+---------+-------+---------+------+-------+------+-------+-------+-------+-------+----------+----------+----------+----------+--------------------+--------------------+--------------------+--------------------+----------+------------+----------+----------+----------+--------------------+----------+--------+---------+--------+----------+--------+------+---------+------+------+---------+--------+------+--------+-----+--------+---------+---------+---------+---------+---------+-----+
# |2023-01-21|      3|2023-01-20|      3|       MG|          DIAMANTINA|      1450|            ARACUAI|    310340|HOSPITAL SAO VICE...|   2134276|      F|1940-05-04|        82|       3|     3082|         9|      1|         1| BRASIL|      1|   MG|          DIAMANTINA|      1450|             ARACUAI|    310340|      1|       2|         2|        2|    1|    1|       2|       1|        2|        1|       2|     2|        2|               NULL|       2|         1|         2|         2|        2|       2|   2|       1|         2|         2|         2|    2|        2|    NULL|     NULL|                NULL|     1|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-01-21|        MG|          DIAMANTINA|      1450|       ARACUAI|    310340|   2|      NULL|      NULL|      NULL|        6|                NULL|      NULL|      1|2023-01-21|         1|             NULL|     NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         5|      NULL|       2|       1|2023-01-27|2023-01-27|2023-01-25|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     2|        2|        2|    NULL|       NULL|      NULL|        2|21/01/2023|     1|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         2|      NULL|      NULL|      NULL|                NULL|                NULL|                NULL|                NULL|      NULL|        NULL|      NULL|         2|      NULL|                NULL|      NULL|    NULL|     NULL|    NULL|      NULL|       2|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-02-08|      6|2023-01-23|      4|       RS|             014 CRS|      1602|CAMPINA DAS MISSOES|    430370|POSTO DE SAUDE SE...|   2250225|      M|1941-07-01|        81|       3|     3081|         6|      1|         1| BRASIL|      1|   RS|             014 CRS|      1602| CAMPINA DAS MISSOES|    430370|      2|       2|         2|        2|    2|    1|       2|       1|        1|        2|       2|     2|     NULL|               NULL|       2|         1|         2|         2|        2|       2|   2|       2|         2|         1|         1|    2|        2|    NULL|        1|         CA PROSTATA|  NULL|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|     NULL|      NULL|     NULL|      NULL|       1|2023-02-01|      NULL|                NULL|      NULL|          NULL|      NULL|   2|      NULL|      NULL|         2|        5|ESPESSAMENTO DE P...|01/02/2023|      1|2023-02-08|         1|             NULL|        1|2023-02-10|         2|      NULL|      NULL|      NULL|      NULL|      NULL|         1|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         5|      NULL|       1|       3|2023-03-02|2023-03-02|2023-02-08|        0|    NULL|     NULL|     NULL|  NULL|     NULL|        1|     NULL|     NULL|    NULL|      1|     2|        2|        2|    NULL|       NULL|      NULL|     NULL|      NULL|  NULL|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|   NULL|         1|16/03/2021|13/04/2021|28/10/2021|86 - COVID-19 SIN...|86 - COVID-19 SIN...|87 - COVID-19 PFI...|86 - COVID-19 SIN...|    210051|      210132|    FG3531|         2|07/06/2022|85 - COVID-19 AST...|21OVCD316Z|       9|     NULL|    NULL|      NULL|       2|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-02-14|      7|2023-02-13|      7|       SC|       FLORIANOPOLIS|      1476|      FLORIANOPOLIS|    420540|INSTITUTO DE ENSI...|     19402|      M|1946-09-26|        76|       3|     3076|         6|      1|      NULL| BRASIL|      1|   SC|       FLORIANOPOLIS|      1476|       FLORIANOPOLIS|    420540|      1|    NULL|         2|        2| NULL| NULL|    NULL|    NULL|     NULL|     NULL|    NULL|  NULL|        1|      ASSINTOMATICO|    NULL|         1|         1|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|  NULL|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|     NULL|      NULL|     NULL|      NULL|       1|2023-02-13|        SC|       FLORIANOPOLIS|      1476| FLORIANOPOLIS|    420540|   2|      NULL|      NULL|         3|     NULL|                NULL|      NULL|      1|2023-02-13|         4|SWAB NASOFARINGEO|        2|2023-02-14|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         4|      NULL|       1|       1|2023-02-17|2023-02-20|2023-02-14|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|   NULL|  NULL|     NULL|     NULL|       5|VIDRO FOSCO|13/02/2023|     NULL|      NULL|     5|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|20/03/2021|17/04/2021|      NULL|86 - COVID-19 SIN...|86 - COVID-19 SIN...|                NULL|86 - COVID-19 SIN...|    210075|      210132|      NULL|         2|30/07/2022|87 - COVID-19 PFI...|    FP7498|    NULL|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-02-16|      7|2023-02-04|      5|       SP|GVE XXIV RIBEIRAO...|      1348|             CAJURU|    350940|CASA DE CARIDADE ...|   2023016|      F|2004-02-19|        18|       3|     3018|         5|      1|      NULL| BRASIL|      1|   SP|GVE XXIV RIBEIRAO...|      1348|              CAJURU|    350940|      2|       2|      NULL|     NULL|    1|    1|       1|    NULL|     NULL|     NULL|    NULL|  NULL|     NULL|               NULL|    NULL|         2|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|  NULL|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|     NULL|      NULL|     NULL|      NULL|       1|2023-07-04|        SP|GVE XXIV RIBEIRAO...|      1348|        CAJURU|    350940|NULL|      NULL|      NULL|         3|        2|                NULL|      NULL|      1|2023-02-07|         1|             NULL|        4|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         5|      NULL|       2|       1|      NULL|2023-02-16|2023-02-22|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|   NULL|  NULL|     NULL|     NULL|    NULL|       NULL|      NULL|     NULL|      NULL|     4|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|   NULL|         1|31/08/2021|28/10/2021|19/07/2022|87 - COVID-19 PFI...|87 - COVID-19 PFI...|87 - COVID-19 PFI...|87 - COVID-19 PFI...|    FF2591|      FG3533|    FT7280|         2|      NULL|                NULL|      NULL|    NULL|     NULL|    NULL|      NULL|       2|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-02-24|      8|2023-02-16|      7|       SP|       GVE I CAPITAL|      1331|          SAO PAULO|    355030|          BP MIRANTE|   6430120|      F|2002-06-13|        20|       3|     3020|         9|      4|         9| BRASIL|      1|   SP|GVE VIII MOGI DAS...|      1333|           GUARULHOS|    351880|      1|    NULL|         2|        2| NULL| NULL|       1|    NULL|     NULL|     NULL|    NULL|  NULL|     NULL|               NULL|    NULL|         2|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|     9|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       2|      NULL|      NULL|                NULL|      NULL|          NULL|      NULL|NULL|      NULL|      NULL|      NULL|     NULL|                NULL|      NULL|      1|2023-02-17|      NULL|             NULL|        1|2023-02-18|         2|      NULL|      NULL|      NULL|      NULL|      NULL|         1|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         5|      NULL|       1|       1|2023-02-17|2023-02-24|2023-02-24|        0|    NULL|     NULL|     NULL|  NULL|     NULL|        1|     NULL|     NULL|    NULL|   NULL|  NULL|     NULL|     NULL|    NULL|       NULL|      NULL|     NULL|      NULL|     4|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|25/06/2021|22/09/2021|10/02/2022|87 - COVID-19 PFI...|87 - COVID-19 PFI...|85 - COVID-19 AST...|87 - COVID-19 PFI...|    FE2083|      FF8844|219VCD291W|         2|      NULL|                NULL|      NULL|       2|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-02-26|      9|2023-02-26|      9|       CE|    1 CRES FORTALEZA|      1519|          FORTALEZA|    230440|SOPAI HOSPITAL IN...|   2526638|      M|2021-04-03|         1|       3|     3001|         6|      4|         5| BRASIL|      1|   CE|    1 CRES FORTALEZA|      1519|           FORTALEZA|    230440|      1|    NULL|      NULL|     NULL|    1|    1|       1|       2|        1|        2|       2|     2|     NULL|               NULL|    NULL|         2|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|  NULL|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|     NULL|      NULL|     NULL|      NULL|       1|2023-02-26|      NULL|                NULL|      NULL|          NULL|      NULL|NULL|      NULL|      NULL|      NULL|     NULL|                NULL|      NULL|      1|2023-02-28|         1|             NULL|        2|2023-03-01|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         4|      NULL|       1|       1|2023-03-03|2023-03-03|2023-02-26|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     2|        2|        2|    NULL|       NULL|      NULL|     NULL|      NULL|     5|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|22/09/2021|04/06/2021|      NULL|87 - COVID-19 PFI...|86 - COVID-19 SIN...|                NULL|87 - COVID-19 PFI...|    FF8842|      210223|      NULL|         2|      NULL|                NULL|      NULL|    NULL|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-02-25|      8|2023-02-24|      8|       RJ|                NULL|      NULL|     RIO DE JANEIRO|    330455|SMS HOSPITAL MUNI...|   2269341|      M|2014-11-06|         8|       3|     3008|         6|      4|         0| BRASIL|      1|   RJ|                NULL|      NULL|      RIO DE JANEIRO|    330455|      1|       2|         2|        2|    1|    1|       2|       2|        2|        1|       2|     2|        2|               NULL|       2|         1|         2|         2|        2|       2|   2|       2|         1|         2|         2|    2|        2|    NULL|        2|                NULL|     2|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-02-25|        RJ|                NULL|      NULL|RIO DE JANEIRO|    330455|   1|2023-02-25|      NULL|         2|        6|                NULL|      NULL|      1|2023-02-25|         1|             NULL|        1|2023-03-02|         2|      NULL|      NULL|      NULL|      NULL|      NULL|         1|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|       1|        1|CORONAVIRUS OC43|         2|      NULL|       1|       1|2023-03-26|2023-03-04|2023-02-27|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     2|        2|        2|       6|       NULL|      NULL|     NULL|      NULL|     5|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|13/06/2022|      NULL|      NULL|86 - COVID-19 SIN...|                NULL|                NULL|86 - COVID-19 SIN...|    210547|        NULL|      NULL|         2|      NULL|                NULL|      NULL|       2|     NULL|    NULL|      NULL|       1|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-02-27|      9|2023-02-25|      8|       PR|  02RS METROPOLITANA|      1356|           CURITIBA|    410690|HOSPITAL UNIVERSI...|     15245|      M|2022-12-03|         2|       2|     2002|         6|      4|         5| BRASIL|      1|   PR|  02RS METROPOLITANA|      1356|            CURITIBA|    410690|      1|    NULL|         2|        2|    1|    1|       2|       1|        1|        1|    NULL|  NULL|     NULL|               NULL|    NULL|         2|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|     9|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-02-25|        PR|  02RS METROPOLITANA|      1356|      CURITIBA|    410690|   2|      NULL|      NULL|         3|        6|                NULL|      NULL|      1|2023-02-27|         1|             NULL|        1|2023-03-03|         2|      NULL|      NULL|      NULL|      NULL|      NULL|         1|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|       1|     NULL|            NULL|         2|      NULL|       1|       1|2023-03-09|2023-03-13|2023-02-27|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|   NULL|  NULL|     NULL|     NULL|    NULL|       NULL|      NULL|     NULL|      NULL|     4|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         2|      NULL|      NULL|      NULL|                NULL|                NULL|                NULL|                NULL|      NULL|        NULL|      NULL|         2|      NULL|                NULL|      NULL|       2|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-03-17|     11|2023-03-12|     11|       SP|    GVE XVI BOTUCATU|      1341|           BOTUCATU|    350750|HOSPITAL UNIMED B...|   7612990|      F|1951-05-05|        71|       3|     3071|         5|      1|         3| BRASIL|      1|   SP|    GVE XVI BOTUCATU|      1341|            BOTUCATU|    350750|      1|       2|         2|        2|    2|    1|       2|       1|        1|        1|       2|     2|        2|               NULL|       2|         1|         2|         2|        2|       2|   2|       1|         2|         2|         2|    2|        2|    NULL|        1|           HAS + DLP|     9|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-03-16|      NULL|                NULL|      NULL|          NULL|      NULL|   2|      NULL|      NULL|      NULL|        6|                NULL|      NULL|      1|2023-03-16|         1|             NULL|        2|2023-03-17|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         4|      NULL|       1|       1|2023-03-19|2023-03-20|2023-03-17|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     2|        2|        2|       2|       NULL|      NULL|     NULL|      NULL|     5|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|      4|      4|      4|      2|         1|24/03/2021|20/04/2021|25/02/2022|86 - COVID-19 SIN...|86 - COVID-19 SIN...|87 - COVID-19 PFI...|86 - COVID-19 SIN...|    210076|      210122|    FN3543|         2|03/01/2023|87 - COVID-19 PFI...|    FX1188|    NULL|     NULL|    NULL|      NULL|       2|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-03-11|     10|2023-03-08|     10|       SP|   GVE XVII CAMPINAS|      1342|           CAMPINAS|    350950|UNIDADE DE PRONTO...|   2022877|      M|2018-01-30|         5|       3|     3005|         6|      4|      NULL| BRASIL|      1|   SP|   GVE XVII CAMPINAS|      1342|            CAMPINAS|    350950|      1|       2|         2|     NULL|    2|    1|       2|       1|        1|        1|       2|     2|        2|               NULL|       2|         1|         2|         2|        2|       2|   1|       2|         2|         2|         2|    2|        2|    NULL|        1|                NULL|     9|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-03-10|        SP|   GVE XVII CAMPINAS|      1342|      CAMPINAS|    350950|   1|2023-03-12|2023-03-14|         2|     NULL|                NULL|      NULL|      1|2023-03-11|         1|             NULL|        2|2023-03-13|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         4|      NULL|       1|       1|2023-03-16|2023-03-20|2023-03-11|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     1|        2|        2|    NULL|       NULL|      NULL|        2|11/03/2023|     2|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|07/11/2022|      NULL|      NULL|86 - COVID-19 SIN...|                NULL|                NULL|86 - COVID-19 SIN...|    220254|        NULL|      NULL|         2|      NULL|                NULL|      NULL|       2|     NULL|    NULL|      NULL|       2|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-01-11|      2|2023-01-07|      1|       PR|        15RS MARINGA|      1369|           COLORADO|    410590|HOSPITAL E MATERN...|   2733307|      F|1964-04-17|        58|       3|     3058|         5|      2|         0| BRASIL|      1|   PR|        15RS MARINGA|      1369|             ATALAIA|    410220|      1|    NULL|         2|        2|    1|    1|       2|       1|        2|        1|       2|     2|        2|               NULL|       2|         1|         2|         2|        2|       2|   2|       2|         1|         2|         2|    2|        1|    NULL|        2|                NULL|     1|2022-05-05|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-01-11|        PR|        15RS MARINGA|      1369|      COLORADO|    410590|   1|2023-01-11|2023-01-19|         2|        6|                NULL|      NULL|      1|2023-01-11|         1|             NULL|     NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         5|      NULL|       1|       1|2023-01-22|2023-01-22|2023-01-11|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     2|        2|        2|       1|       NULL|      NULL|        2|11/01/2023|     1|      NULL|     NULL|         1|       1|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|20/05/2021|02/09/2021|21/02/2022|85 - COVID-19 AST...|85 - COVID-19 AST...|85 - COVID-19 AST...|85 - COVID-19 AST...|214VCD067Z|  217VCD242Z|21OVCD303W|         2|      NULL|                NULL|      NULL|       2|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL| NULL|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-01-19|      3|2023-01-17|      3|       SC|       FLORIANOPOLIS|      1476|      FLORIANOPOLIS|    420540|INSTITUTO DE ENSI...|     19402|      M|1937-09-14|        85|       3|     3085|         6|      1|      NULL| BRASIL|      1|   SC|       FLORIANOPOLIS|      1476|       FLORIANOPOLIS|    420540|      1|    NULL|         2|        2| NULL| NULL|    NULL|       1|     NULL|     NULL|    NULL|  NULL|     NULL|               NULL|    NULL|         2|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|  NULL|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|     NULL|      NULL|     NULL|      NULL|       1|2023-01-18|        SC|       FLORIANOPOLIS|      1476| FLORIANOPOLIS|    420540|   1|2023-01-18|      NULL|         3|     NULL|                NULL|      NULL|      1|2023-01-18|         4| SWAB NASOFARINGE|        5|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         5|      NULL|       1|       1|2023-01-22|2023-01-23|2023-01-19|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|   NULL|  NULL|     NULL|     NULL|    NULL|       NULL|      NULL|        2|18/01/2023|     1|      NULL|     NULL|         1|       1|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|      NULL|      NULL|      NULL|                NULL|                NULL|                NULL|                NULL|      NULL|        NULL|      NULL|         2|12/04/2022|88 - COVID-19 JAN...|   1875739|    NULL|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL| NULL|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-01-23|      4|2023-01-19|      3|       SP|GVE XXIX SAO JOSE...|      1354|          CATANDUVA|    351110|HOSPITAL PADRE AL...|   2089327|      F|2016-10-06|         6|       3|     3006|         6|      1|         1| BRASIL|      1|   SP|GVE XXIX SAO JOSE...|      1354|             ITAJOBI|    352190|      1|    NULL|         2|        2|    2|    1|       2|       1|        1|        1|       2|     2|        2|               NULL|    NULL|         2|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|     9|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-01-20|        SP|GVE XXIX SAO JOSE...|      1354|     CATANDUVA|    351110|   2|      NULL|      NULL|         2|        6|                NULL|      NULL|      1|2023-01-21|         1|             NULL|        2|2023-01-23|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         4|      NULL|       1|       1|2023-01-24|2023-01-30|2023-01-23|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     2|        2|        2|       6|       NULL|      NULL|        2|21/01/2023|     2|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|25/02/2022|      NULL|      NULL|99 - COVID-19 PED...|                NULL|                NULL|99 - COVID-19 PED...|    FP8290|        NULL|      NULL|         2|      NULL|                NULL|      NULL|       2|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL| NULL|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-01-17|      3|2023-01-11|      2|       DF|                NULL|      NULL|           BRASILIA|    530010|HOSPITAL REGIONAL...|     10480|      M|2022-11-12|         2|       2|     2002|         6|      4|         5| BRASIL|      1|   DF|                NULL|      NULL|           CEILANDIA|    530040|      1|    NULL|         2|        2|    1|    1|       2|       2|        1|        2|       2|     2|        2|               NULL|    NULL|         2|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|  NULL|      NULL|      9|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-01-11|        DF|                NULL|      NULL|      BRASILIA|    530010|   2|      NULL|      NULL|         2|        6|                NULL|      NULL|      1|2023-01-11|         1|             NULL|        1|2023-01-12|         2|      NULL|      NULL|      NULL|      NULL|      NULL|         1|      1|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         2|      NULL|       1|       1|2023-01-15|2023-01-17|2023-01-17|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     2|        2|        2|       6|       NULL|      NULL|        2|11/01/2023|     2|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         2|      NULL|      NULL|      NULL|                NULL|                NULL|                NULL|                NULL|      NULL|        NULL|      NULL|         2|      NULL|                NULL|      NULL|       2|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-01-19|      3|2023-01-17|      3|       PI|     1 GRS  PARNAIBA|      1868|           PARNAIBA|    220770|HOSPITAL ESTADUAL...|   8015899|      M|2016-08-09|         6|       3|     3006|         6|      4|      NULL| BRASIL|      1|   PI|     1 GRS  PARNAIBA|      1868|            PARNAIBA|    220770|      1|    NULL|      NULL|     NULL| NULL|    1|    NULL|    NULL|        1|     NULL|    NULL|  NULL|     NULL|               NULL|    NULL|         2|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|  NULL|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|     NULL|      NULL|     NULL|      NULL|       1|2023-01-19|        PI|     1 GRS  PARNAIBA|      1868|      PARNAIBA|    220770|   2|      NULL|      NULL|      NULL|     NULL|                NULL|      NULL|      1|2023-01-19|         1|             NULL|        5|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|      NULL|      NULL|    NULL|    NULL|      NULL|      NULL|2023-01-20|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|   NULL|  NULL|     NULL|     NULL|    NULL|       NULL|      NULL|     NULL|      NULL|     4|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|      4|      4|      4|      2|         2|      NULL|      NULL|      NULL|                NULL|                NULL|                NULL|                NULL|      NULL|        NULL|      NULL|         2|      NULL|                NULL|      NULL|    NULL|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL| NULL|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-01-26|      4|2023-01-15|      3|       DF|                NULL|      NULL|           BRASILIA|    530010|HOSPITAL SANTA LUCIA|   2815966|      F|1929-08-19|        93|       3|     3093|         9|      9|         9| BRASIL|      1|   DF|                NULL|      NULL|               GUARA|    530070|      1|    NULL|         1|        9| NULL| NULL|    NULL|    NULL|     NULL|     NULL|    NULL|  NULL|        1|SATURACAO E ASTENIA|    NULL|         1|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|        1|       HAS + INSONIA|  NULL|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        9|      NULL|     NULL|      NULL|       1|2023-01-11|        DF|                NULL|      NULL|      BRASILIA|    530010|   1|2023-01-11|2023-01-13|         2|     NULL|                NULL|      NULL|      1|2023-01-17|         1|             NULL|        2|2023-01-17|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         4|      NULL|       1|       1|2023-01-25|2023-01-26|2023-01-26|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|   NULL|  NULL|     NULL|     NULL|    NULL|       NULL|      NULL|     NULL|      NULL|     9|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|02/02/2021|04/05/2021|      NULL|85 - COVID-19 AST...|85 - COVID-19 AST...|                NULL|85 - COVID-19 AST...|  4120Z005|213VCD004ZVA|      NULL|         2|13/04/2022|87 - COVID-19 PFI...|    FN2724|       9|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-01-13|      2|2023-01-05|      1|       SP|      GVE XXV SANTOS|      1349|             SANTOS|    354850|CASA DE SAUDE SANTOS|   3008398|      F|1940-09-11|        82|       3|     3082|         5|      1|      NULL| BRASIL|      1|   SP|      GVE XXV SANTOS|      1349|              SANTOS|    354850|      1|       2|         2|        2|    1| NULL|    NULL|       1|     NULL|        1|    NULL|  NULL|     NULL|               NULL|    NULL|         1|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|        1|    NULL|        1|HAS, HIPOTIREOIDI...|     1|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-01-13|        SP|      GVE XXV SANTOS|      1349|        SANTOS|    354850|   1|2023-02-01|      NULL|         2|        5|                NULL|13/01/2023|      1|2023-01-13|         1|             NULL|        2|2023-01-13|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         4|      NULL|       1|       2|2023-02-24|2023-04-04|2023-01-23|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|   NULL|  NULL|     NULL|     NULL|    NULL|       NULL|      NULL|        2|13/01/2023|     2|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|10/05/2021|29/07/2021|26/05/2022|85 - COVID-19 AST...|85 - COVID-19 AST...|86 - COVID-19 SIN...|85 - COVID-19 AST...|214VCD048Z|  216VCD199W|    210544|         2|      NULL|                NULL|      NULL|       2|     NULL|    NULL|      NULL|       2|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-02-06|      6|2023-02-05|      6|       AM|      BAIXO AMAZONAS|      5589|          PARINTINS|    130340|HOSPITAL REGIONAL...|   3210243|      M|1962-05-16|        60|       3|     3060|         6|      5|      NULL| BRASIL|      1|   AM|      BAIXO AMAZONAS|      5589|            NHAMUNDA|    130300|      2|    NULL|      NULL|     NULL| NULL|    1|    NULL|       1|     NULL|     NULL|    NULL|  NULL|     NULL|               NULL|    NULL|         2|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|      NULL|      NULL|      NULL| NULL|     NULL|    NULL|     NULL|                NULL|  NULL|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|     NULL|      NULL|     NULL|      NULL|       1|2023-02-05|        AM|      BAIXO AMAZONAS|      5589|     PARINTINS|    130340|NULL|      NULL|      NULL|      NULL|     NULL|                NULL|      NULL|      1|2023-02-05|         1|             NULL|        2|2023-02-16|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         4|      NULL|       1|       1|2023-02-10|2023-04-25|2023-02-06|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|   NULL|  NULL|     NULL|     NULL|    NULL|       NULL|      NULL|        2|05/02/2023|     2|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|22/01/2021|12/02/2021|23/12/2021|86 - COVID-19 SIN...|86 - COVID-19 SIN...|87 - COVID-19 PFI...|86 - COVID-19 SIN...| 202010025|   202010028|    FL1939|         2|14/06/2022|87 - COVID-19 PFI...|    FN2724|    NULL|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-02-20|      8|2023-02-14|      7|       SP|   GVE XVII CAMPINAS|      1342|           CAMPINAS|    350950|UNIDADE DE PRONTO...|   5874998|      M|1956-05-23|        66|       3|     3066|         6|      4|      NULL| BRASIL|      1|   SP|   GVE XVII CAMPINAS|      1342|            CAMPINAS|    350950|      1|    NULL|         2|        2|    1|    1|       2|       1|        1|        1|       2|     2|     NULL|               NULL|    NULL|         1|      NULL|      NULL|     NULL|    NULL|NULL|    NULL|         1|      NULL|      NULL| NULL|     NULL|    NULL|        1|       AVC - SEQUELA|     2|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-02-27|        SP|   GVE XVII CAMPINAS|      1342|      CAMPINAS|    350950|NULL|      NULL|      NULL|      NULL|        2|                NULL|21/02/2023|      1|2023-02-25|      NULL|             NULL|        5|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         4|      NULL|    NULL|       2|2023-02-27|2024-07-22|2023-02-20|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     2|        2|        2|    NULL|       NULL|      NULL|        2|25/02/2023|     2|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|11/02/2021|31/08/2021|04/02/2022|85 - COVID-19 AST...|85 - COVID-19 AST...|87 - COVID-19 PFI...|85 - COVID-19 AST...|  4120Z004|  217VCD221W|    FL3211|         2|27/05/2022|88 - COVID-19 JAN...|   2363673|       2|     NULL|    NULL|      NULL|    NULL|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# |2023-01-24|      4|2023-01-22|      4|       SC|           JOINVILLE|      1565|          JOINVILLE|    420910|HOSPITAL REGIONAL...|   2436450|      F|1949-06-15|        73|       3|     3073|         5|      1|      NULL| BRASIL|      1|   SC|           JOINVILLE|      1565|SAO FRANCISCO DO SUL|    421620|      1|       2|         2|     NULL|    2|    2|       2|       1|        1|        1|       2|     2|        2|               NULL|       2|         1|         2|         2|        2|       2|   2|       1|         2|         2|         2|    2|        2|    NULL|        1|     HIPOTIREOIDISMO|     2|      NULL|   NULL|      NULL|      NULL|      NULL|     NULL|     NULL|        2|      NULL|     NULL|      NULL|       1|2023-01-24|        SC|           JOINVILLE|      1565|     JOINVILLE|    420910|   1|2023-01-24|2023-02-14|         1|        6|                NULL|      NULL|      1|2023-01-24|         4|   S. NASOFARINGE|        2|2023-01-26|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|      NULL|   NULL|     NULL|     NULL|     NULL|     NULL|     NULL|     NULL|    NULL|    NULL|     NULL|            NULL|         5|      NULL|       1|       3|2023-02-22|2023-02-23|2023-01-24|        0|    NULL|     NULL|     NULL|  NULL|     NULL|     NULL|     NULL|     NULL|    NULL|      2|     2|        2|        2|       2|       NULL|23/01/2023|     NULL|      NULL|     4|      NULL|     NULL|      NULL|    NULL|  NULL|    NULL|    NULL|    NULL|    NULL|    NULL|     NULL|     NULL|   NULL|     NULL|  NULL|   NULL|  NULL|   NULL|   NULL|   NULL|      2|         1|12/04/2021|27/04/2021|24/02/2022|86 - COVID-19 SIN...|86 - COVID-19 SIN...|85 - COVID-19 AST...|86 - COVID-19 SIN...|    210131|      210136|219VCD277Z|         2|      NULL|                NULL|      NULL|       2|     NULL|    NULL|      NULL|       2|  NULL|     NULL|  NULL|  NULL|     NULL|    NULL|  NULL|    NULL|    2|    NULL|     NULL|     NULL|     NULL|     NULL|     NULL| NULL|
# +----------+-------+----------+-------+---------+--------------------+----------+-------------------+----------+--------------------+----------+-------+----------+----------+--------+---------+----------+-------+----------+-------+-------+-----+--------------------+----------+--------------------+----------+-------+--------+----------+---------+-----+-----+--------+--------+---------+---------+--------+------+---------+-------------------+--------+----------+----------+----------+---------+--------+----+--------+----------+----------+----------+-----+---------+--------+---------+--------------------+------+----------+-------+----------+----------+----------+---------+---------+---------+----------+---------+----------+--------+----------+----------+--------------------+----------+--------------+----------+----+----------+----------+----------+---------+--------------------+----------+-------+----------+----------+-----------------+---------+----------+----------+----------+----------+----------+----------+----------+----------+-------+---------+---------+---------+---------+---------+---------+--------+--------+---------+----------------+----------+----------+--------+--------+----------+----------+----------+---------+--------+---------+---------+------+---------+---------+---------+---------+--------+-------+------+---------+---------+--------+-----------+----------+---------+----------+------+----------+---------+----------+--------+------+--------+--------+--------+--------+--------+---------+---------+-------+---------+------+-------+------+-------+-------+-------+-------+----------+----------+----------+----------+--------------------+--------------------+--------------------+--------------------+----------+------------+----------+----------+----------+--------------------+----------+--------+---------+--------+----------+--------+------+---------+------+------+---------+--------+------+--------+-----+--------+---------+---------+---------+---------+---------+-----+
# only showing top 20 rows
